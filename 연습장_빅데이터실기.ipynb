# %%
import numpy as np
import pandas as pd
import os

# %%
repo_url = 'https://gist.github.com/seankross/a412dfbd88b3db70b74b'
# %cd -q /content
repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))
# !git clone {repo_url} --quiet
# %cd -q {repo_dir_path}
# !git pull -q

# %%
df= pd.read_csv('mtcars.csv')

# %%
df.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
df1=df.copy()
df1=df1.astype({'cyl':'object'})
print(df1.dtypes)
# Out:
# model     object
# mpg      float64
# cyl       object
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
df1['cyl'].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
df.shape
# Out:
# (32, 12)

# %%
mpg_mean= df['mpg'].mean()

# %%
mpg_median =  df['mpg'].median()

# %%
mpg_mode = df['mpg'].mode() # ㅊㅂㄱ

# %%
mpg_var = df ['mpg'].var() #분산

# %%
mpg_std = df['mpg'].std() #표준편차

# %%
Q1 = df['mpg'].quantile(0.75) #4분위

# %%
mpg_max = df['mpg'].max()

# %%
mpg_min= df['mpg'].min()

# %%
#왜곡도
mpg_skew = df['mpg'].skew()

# %%
mpg_sum=df['mpg'].sum()

# %%
len(df['mpg'])
# Out:
# 32

# %%
import seaborn as sns
df=sns.load_dataset('iris')
df.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df=pd.read_csv('mtcars.csv')

# %%
df.loc[3,'mpg']
# Out:
# 21.4

# %%
df.loc[1:2,'mpg']
# Out:
# 1    21.0
# 2    22.8
# Name: mpg, dtype: float64

# %%
df.loc[0:3,'mpg':'disp']
# Out:
#     mpg  cyl   disp
# 0  21.0    6  160.0
# 1  21.0    6  160.0
# 2  22.8    4  108.0
# 3  21.4    6  258.0

# %%
#열제거
df.drop(columns=['mpg'])
# Out:
#                   model  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0             Mazda RX4    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1         Mazda RX4 Wag    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2            Datsun 710    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3        Hornet 4 Drive    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4     Hornet Sportabout    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5               Valiant    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6            Duster 360    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7             Merc 240D    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8              Merc 230    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9              Merc 280    6  167.6  123  3.92  3.440  18.30   1   0     4
# 10            Merc 280C    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df2=df.copy() #열추가
df2['new']=df['mpg']+10
df2
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
condition =(df['mpg']==21.0)
len(condition)
# Out:
# 32

# %%
df[df['cyl']==4]
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 2      1
# 7      2
# 8      2
# 17     1
# ...

# %%
df.sort_values('mpg',ascending=True)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
df['hp']=np.where(df['hp']>=205,205,df['hp'])
#205가 넘는 값은 205로 처리하고 그외는 hp로 처리

# %%
df.sort_values('hp',ascending=False)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 16    Chrysler Imperial  14.7    8  440.0  205  3.23  5.345  17.42   0   0
# 30        Maserati Bora  15.0    8  301.0  205  3.54  3.570  14.60   0   1
# 28       Ford Pantera L  15.8    8  351.0  205  4.22  3.170  14.50   0   1
# 6            Duster 360  14.3    8  360.0  205  3.21  3.570  15.84   0   0
# 23           Camaro Z28  13.3    8  350.0  205  3.73  3.840  15.41   0   0
# 15  Lincoln Continental  10.4    8  460.0  205  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# ...

# %%
df=sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
#결측치 확인
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna(axis=0).shape #행기준 결측치 제거
df.dropna(axis=1).shape #열기준 row
# Out:
# (182, 15)

# %%
df2=df.copy() #중앙값으로 결측치 대체
median_age = df['age'].median()
df['age']=df2['age'].fillna(median_age)

# %%
df.isnull().sum() #age 결측치 대체됨
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
 #sns 로 matplotlib plt처럼
 sns.boxplot(df['age'])
# Out:
# <Axes: >

# %%
#데이터 표준화, Z =(개별값-평균/표준편차)

# %%
mean_age = df['age'].mean()
std_age = df['age'].std()

# %%
znorm = (df['age']-mean_age) / std_age
znorm
# Out:
# 0     -0.565419
# 1      0.663488
# 2     -0.258192
# 3      0.433068
# 4      0.433068
#          ...
# 886   -0.181385
# 887   -0.795839
# 888   -0.104579
# 889   -0.258192
# 890    0.202648
# Name: age, Length: 891, dtype: float64

# %%
cond1 =(znorm>3) #+-3Z 기준
cond2 =(znorm<-3)

# %%
df1=df.copy()
df1=df1.drop_duplicates() #중복값삭제

# %%
df=pd.read_csv('mtcars.csv')

# %%
from sklearn.preprocessing import StandardScaler
zscaler = StandardScaler()
df['msg']=zscaler.fit_transform(df[['msg']])

# %%
from sklearn.preprocessing import MinMaxScaler
mscaler = MinMaxScaler
df['msg']=mscaler.fit_transform(df['mpg'])

# %%
df_sum=pd.concat([df1,df2], axis=0)

# %%
print(df_sum.head())
print(df_sum.shape)
df1=df.loc[:,'sepal_length':'petal_length']
df2=df.loc[:['petal_width','species']]

# %%
#날짜 변경
# df['date']= pd.to_datetime(df['date'])
# csv 파일 없어서 이걸로 대체

# %%
#df[df['date'].between('2023-01-01','2023-02-23')]
